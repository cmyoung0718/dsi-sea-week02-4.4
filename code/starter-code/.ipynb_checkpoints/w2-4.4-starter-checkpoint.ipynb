# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Lab

# %% [markdown]
# ### Load your database here recruit!

# %%
df= pd.read_csv('./../../assets/marvel.csv')
print df.head()
# Out:
#    page_id                                 name  \
# 0     1678            Spider-Man (Peter Parker)
# 1     7139      Captain America (Steven Rogers)
# 2    64786  Wolverine (James \"Logan\" Howlett)
# 3     1868    Iron Man (Anthony \"Tony\" Stark)
# 4     2460                  Thor (Thor Odinson)
#
#                                    urlslug                ID  \
# 0              \/Spider-Man_(Peter_Parker)   Secret Identity
# 1        \/Captain_America_(Steven_Rogers)   Public Identity
# 2  \/Wolverine_(James_%22Logan%22_Howlett)   Public Identity
# 3    \/Iron_Man_(Anthony_%22Tony%22_Stark)   Public Identity
# 4                    \/Thor_(Thor_Odinson)  No Dual Identity
#
#                 ALIGN         EYE        HAIR              SEX  GSM  \
# 0     Good Characters  Hazel Eyes  Brown Hair  Male Characters  NaN
# 1     Good Characters   Blue Eyes  White Hair  Male Characters  NaN
# 2  Neutral Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 3     Good Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 4     Good Characters   Blue Eyes  Blond Hair  Male Characters  NaN
#
#                ALIVE  APPEARANCES FIRST APPEARANCE    Year
# 0  Living Characters       4043.0           Aug-62  1962.0
# 1  Living Characters       3360.0           Mar-41  1941.0
# 2  Living Characters       3061.0           Oct-74  1974.0
# 3  Living Characters       2961.0           Mar-63  1963.0
# 4  Living Characters       2258.0           Nov-50  1950.0

# %% [markdown]
# ### Here are our findings from extensive research and hero fighting. Run this field once. It will set up all of your data for you. Feel free to add additional weaknesses and affinities if you feel like it!

# %%
def randomly(length):
    return np.random.randint(0, length, size = 1)[0]

def pull_unique(length, arr):
    this_rand = randomly(length)
    while this_rand in arr:
        this_rand = randomly(length)
    return this_rand


value_length = len(df) + len(df) / 20

#the hero's weakness
weaknesses = ["ponies","butterflies","apple pie","spiders",
              "giant robots","fireballs","tv static","gerbils",
              "lactose","Walmart","boomerangs","kangaroos","true love", "Shaq"]

#the hero's favorite hobby
affinities = ["balloons","rubber ducks","plasma laser guns","ghosts",
              "clouds","bouncy balls","milkshakes","storms",
              "preschools","Panda Express","shag rugs","bubble gum","Kanye West"]

super_weaknesses = [weaknesses[randomly(len(weaknesses))] for x in range(value_length)]
affinities = [affinities[randomly(len(affinities))] for x in range(value_length)]
killability = [randomly(10) + 1 for x in range(value_length)]
more_ids = list(df['page_id'])

for x in range(value_length - len(df)):
    unique = [pull_unique(100000,more_ids)]
    more_ids += unique
    
raw_data = {
        'page_id' : more_ids,
        'Weaknesses': super_weaknesses,
        'Affinities': affinities,
        'Killability': killability}

print raw_data
# Out:
# {'Killability': [3, 3, 7, 10, 2, 6, 7, 8, 7, 7, 5, 7, 10, 6, 4, 5, 3, 9, 8, 8, 8, 8, 6, 2, 2, 5, 6, 2, 8, 6, 3, 2, 3, 7, 6, 8, 6, 6, 10, 10, 3, 5, 8, 6, 4, 1, 4, 4, 6, 3, 10, 5, 8, 3, 7, 9, 3, 5, 9, 3, 9, 5, 5, 10, 3, 1, 8, 4, 9, 1, 9, 5, 9, 1, 10, 8, 7, 6, 3, 5, 6, 7, 4, 6, 5, 9, 8, 5, 5, 8, 2, 8, 9, 10, 10, 1, 5, 4, 8, 1, 8, 6, 4, 1, 7, 4, 9, 8, 2, 6, 7, 9, 8, 2, 10, 6, 9, 8, 5, 10, 4, 9, 5, 1, 6, 4, 3, 3, 3, 9, 2, 3, 4, 4, 10, 9, 7, 9, 2, 3, 5, 8, 5, 8, 8, 9, 5, 1, 4, 9, 8, 4, 9, 5, 2, 7, 2, 9, 7, 4, 9, 8, 8, 6, 5, 7, 5, 1, 6, 7, 3, 4, 10, 10, 5, 10, 2, 3, 6, 8, 5, 6, 6, 1, 1, 5, 2, 7, 10, 3, 2, 9, 9, 7, 3, 6, 9, 6, 7, 1, 3, 8, 6, 4, 1, 7, 1, 10, 6, 6, 4, 10, 3, 5, 3, 3, 5, 4, 10, 5, 9, 9, 5, 1, 4, 5, 7, 3, 10, 10, 7, 2, 1, 5, 10, 9, 7, 3, 2, 7, 2, 2, 3, 2, 3, 7, 2, 7, 1, 8, 6, 9, 6, 7, 8, 10, 10, 5, 10, 2, 6, 4, 5, 3, 9, 3, 4, 8, 10, 2, 8, 7, 5, 10, 3, 6, 6, 4, 1, 2, 4, 7, 1, 1, 3, 1, 9, 6, 9, 6, 8, 1, 1, 7, 7, 8, 4, 8, 8, 8, 6, 9, 2, 5, 3, 5, 1, 8, 4, 7, 2, 3, 5, 7, 3,
# 16381    84492.0
# 16382    12706.0
# 16383    25013.0
# 16384    36005.0
# 16385      307.0
# 16386    88836.0
# 16387    77487.0
# 16388    32239.0
# 16389    61552.0
# 16390    59282.0
# 16391    93073.0
# 16392    75952.0
# 16393    38457.0
# 16394    22652.0
# 16395    47873.0
# 16396    99195.0
# 16397    71312.0
# 16398    30298.0
# 16399    95039.0
# 16400     5463.0
# 16401    53965.0
# 16402     9978.0
# 16403    96805.0
# 16404    95949.0
# 16405     9606.0
#           ...
# 17164    55952.0
# 17165    28132.0
# 17166    50035.0
# 17167    21157.0
# 17168    71932.0
# 17169    67766.0
# 17170    15618.0
# 17171    71503.0
# 17172    73971.0
# 17173    25984.0
# 17174    57083.0
# 17175      447.0
# 17176    74470.0
# 17177    89403.0
# 17178    62024.0
# 17179       80.0
# 17180    45231.0
# 17181      155.0
# 17182    30275.0
# 17183    86914.0
# 17184    91424.0
# 17185    75975.0
# 17186      799.0
# 17187    82546.0
# 17188    28408.0
# 17189    67676.0
# 17190    99026.0
# 17191    84524.0
# 17192    79526.0
# 17193    27632.0
# Name: page_id, dtype: float64

# %% [markdown]
# ### Perform an inner join with your dataframes. This should automatically throw out the values that don't map to each other

# %%
inner_merge = pd.merge(df, marvel, how='inner', on='page_id')
inner_merge.head()
# Out:
#    page_id                                 name  \
# 0     1678            Spider-Man (Peter Parker)
# 1     7139      Captain America (Steven Rogers)
# 2    64786  Wolverine (James \"Logan\" Howlett)
# 3     1868    Iron Man (Anthony \"Tony\" Stark)
# 4     2460                  Thor (Thor Odinson)
#
#                                    urlslug                ID  \
# 0              \/Spider-Man_(Peter_Parker)   Secret Identity
# 1        \/Captain_America_(Steven_Rogers)   Public Identity
# 2  \/Wolverine_(James_%22Logan%22_Howlett)   Public Identity
# 3    \/Iron_Man_(Anthony_%22Tony%22_Stark)   Public Identity
# 4                    \/Thor_(Thor_Odinson)  No Dual Identity
#
#                 ALIGN         EYE        HAIR              SEX  GSM  \
# 0     Good Characters  Hazel Eyes  Brown Hair  Male Characters  NaN
# 1     Good Characters   Blue Eyes  White Hair  Male Characters  NaN
# 2  Neutral Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 3     Good Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 4     Good Characters   Blue Eyes  Blond Hair  Male Characters  NaN
#
#                ALIVE  APPEARANCES FIRST APPEARANCE    Year    Affinities  \
# 0  Living Characters       4043.0           Aug-62  1962.0    bubble gum
# 1  Living Characters       3360.0           Mar-41  1941.0     shag rugs
# 2  Living Characters       3061.0           Oct-74  1974.0  rubber ducks
# 3  Living Characters       2961.0           Mar-63  1963.0        storms
# 4  Living Characters       2258.0           Nov-50  1950.0  rubber ducks
#
#    Killability    Weaknesses
# 0            3     apple pie
# 1            3  giant robots
# 2            7     tv static
# 3           10  giant robots
# 4            2       Walmart

# %% [markdown]
# ### The Brain ([Leader of the League/Brotherhood of Evil](https://en.wikipedia.org/wiki/Brain_(comics))) has asked you to evaluate your data. Since funds are short, the league wants to know which Good Aligned hero weakness is most beneficial to invest in. Make sure the heros are still alive. No use investing in problems we don't have.

# %%
# Looks like you need to invest more into fireballs.

pd.value_counts(inner_merge.ix[(inner_merge['ALIVE'] == 'Living Characters') & 
                              (inner_merge['ALIGN'] == 'Good Characters')]['Weaknesses'])
# Out:
# fireballs       302
# spiders         283
# butterflies     280
# boomerangs      279
# Shaq            275
# kangaroos       272
# apple pie       270
# ponies          268
# tv static       267
# Walmart         266
# lactose         264
# giant robots    261
# gerbils         258
# true love       248
# Name: Weaknesses, dtype: int64

# %% [markdown]
# ### Phobia ([League/Brotherhood of Evil Platinum Member](https://en.wikipedia.org/wiki/Phobia_(comics)) is more interested in the affinities of the Good Aligned heros with their identities exposed. Which affinity would you recommend the guild invest in?

# %%
# I would suggest investing in bouncy.

pd.value_counts(inner_merge.ix[(inner_merge['ALIVE'] == 'Living Characters') &
                               (inner_merge['ALIGN'] == 'Good Characters') &
                              (inner_merge['ID'] == 'Public Identity')]['Affinities'])
# Out:
# bouncy balls         120
# Panda Express        119
# bubble gum           116
# clouds               114
# Kanye West           111
# storms               107
# preschools           106
# plasma laser guns    104
# shag rugs            102
# ghosts                95
# balloons              95
# rubber ducks          93
# milkshakes            91
# Name: Affinities, dtype: int64

# %% [markdown]
# ### Madame Rouge ([League/Brotherhood of Evil House Mom](https://en.wikipedia.org/wiki/Madame_Rouge)) is concerned about the killability of our heros based on their alignment. Let's create a table for her, comparing our hero's alignments with their killability.

# %%
align_kill = pd.pivot_table(inner_merge, values=['Killability'], index=['ALIGN'])
align_kill
# Out:
#                     Killability
# ALIGN
# Bad Characters         5.574702
# Good Characters        5.488999
# Neutral Characters     5.535326

# %% [markdown]
# ### Madame Rouge ([League/Brotherhood of Evil House Mom](https://en.wikipedia.org/wiki/Madame_Rouge)) is also concerned about the affinity of our heros based on their alignment. Let's create a table for her, comparing our hero's alignments with their affinities.

# %%
align_aff = pd.pivot_table(inner_merge, values=['Affinities'], index=['ALIGN', 'name'], aggfunc=sum)
align_aff
# Out:
#                                                                               Affinities
# ALIGN              name
# Bad Characters     11-Ball (Earth-616)                                            clouds
#                    14 (Earth-616)                                             Kanye West
#                    6-Ball (Earth-616)                                             ghosts
#                    6R (Earth-616)                                             bubble gum
#                    8-Ball (Hobgoblin) (Earth-616)                             Kanye West
#                    8-Ball II (Earth-616)                                          ghosts
#                    88 (Earth-616)                                             preschools
#                    9-Ball (Earth-616)                                         bubble gum
#                    A (Earth-616)                                              bubble gum
#                    A'yin (Earth-616)                                       Panda Express
#                    A3 (Earth-616)                                                 ghosts
#                    Aa-Thak (Earth-616)                                            ghosts
#                    Aaidan Blomfield (Earth-616)                                shag rugs
#                    Aaron Cashin (Earth-616)                                 bouncy balls
#                    Aaron Chord (Earth-616)                                     shag rugs
#                    Aaron Nicholson (Earth-616)                                    storms
#                    Aaron Salomon (Earth-616)                           plasma laser guns
#                    Aaron Soames (Earth-616)                                       ghosts
#                    Aaron Thorne (Earth-616)                                   milkshakes
#                    Aaron Verne (Earth-616)                                    bubble gum
#                    Abadon (Earth-616)                                         bubble gum
#                    Aban (Earth-616)                                        Panda Express
#                    Abara and Cadabra (Earth-616)                                  storms
#                    Abbas al-Abbad (Earth-616)                                 preschools
#                    Abbess Horror (Earth-616)                                  bubble gum
#                    Abd-el-Hazred (Earth-616)                               Panda Express
#                    Abdi (Earth-616)                                         bouncy balls
#                    Able Doone (Earth-616)                                     Kanye West
#                    Abner Jonas (Earth-616)                                  bouncy balls
#                    Abraham James (Earth-616)                                    balloons
# ...                                                                                  ...
# Neutral Characters Yod (Earth-616)                                             shag rugs
#                    Yorlo (Earth-616)                                           shag rugs
#                    Yoshi (Earth-616)                                              ghosts
#                    Yoshi's mother (Earth-616)                                  shag rugs
#                    Young Soo Pock (Earth-616)                               bouncy balls
#                    Yruku (Earth-616)                                          Kanye West
#                    Yukio (Earth-616)                                          bubble gum
#                    Yuri Topolov (Earth-616)                                       ghosts
#                    Yuriko Takiguchi (Earth-616)                               Kanye West
#                    Yvette Steckley (Earth-616)                                  balloons
#                    Za'ken (Earth-616)                                             ghosts
#                    Zahvut Dragunov (Earth-616)                                preschools
#                    Zalme (Earth-616)                                              clouds
#                    Zalph (Earth-616)                                              clouds
#                    Zamanathan Rambunazeth (Earth-616)                           balloons
#                    Zarathos (Earth-616)                                           clouds
#                    Zarin (Eternal) (Earth-616)                                preschools
#                    Zeeshan (Earth-616)                                 plasma laser guns
#                    Zephyr (Earth-616)                                  plasma laser guns
#                    Zero G. Priestly (Legion Personality) (Earth-616)        bouncy balls
#                    Zeus Panhellenios (Earth-616)                       plasma laser guns
#                    Zimmer (Earth-616)                                             clouds
#                    Ziran (Earth-616)                                          preschools
#                    Zius (Earth-616)                                           bubble gum
#                    Zoe Ishihara (Earth-616)                                       ghosts
#                    Zon (Earth-616)                                            bubble gum
#                    Zoro (Earth-616)                                         bouncy balls
#                    Zubar (Legion Personality) (Earth-616)                   rubber ducks
#                    Zzutak's Enemy (Earth-616)                                     ghosts
#                    \"Spider-Girl\" (Mutant\/Spider Clone) (Earth-616)       rubber ducks
#
# [13564 rows x 1 columns]

# %% [markdown]
# ### General Immortus ([League/Brotherhood of Founding Member](https://en.wikipedia.org/wiki/General_Immortus)) took a look at your data and is concerned. Shouldn't we be adding all of our new data to our database? Let's merge all of our columns without regard to if they align or not.

# %%
outer_merge = pd.merge(df, marvel, how='outer', on='page_id')
outer_merge.head()
# Out:
#    page_id                                 name  \
# 0   1678.0            Spider-Man (Peter Parker)
# 1   7139.0      Captain America (Steven Rogers)
# 2  64786.0  Wolverine (James \"Logan\" Howlett)
# 3   1868.0    Iron Man (Anthony \"Tony\" Stark)
# 4   2460.0                  Thor (Thor Odinson)
#
#                                    urlslug                ID  \
# 0              \/Spider-Man_(Peter_Parker)   Secret Identity
# 1        \/Captain_America_(Steven_Rogers)   Public Identity
# 2  \/Wolverine_(James_%22Logan%22_Howlett)   Public Identity
# 3    \/Iron_Man_(Anthony_%22Tony%22_Stark)   Public Identity
# 4                    \/Thor_(Thor_Odinson)  No Dual Identity
#
#                 ALIGN         EYE        HAIR              SEX  GSM  \
# 0     Good Characters  Hazel Eyes  Brown Hair  Male Characters  NaN
# 1     Good Characters   Blue Eyes  White Hair  Male Characters  NaN
# 2  Neutral Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 3     Good Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 4     Good Characters   Blue Eyes  Blond Hair  Male Characters  NaN
#
#                ALIVE  APPEARANCES FIRST APPEARANCE    Year    Affinities  \
# 0  Living Characters       4043.0           Aug-62  1962.0    bubble gum
# 1  Living Characters       3360.0           Mar-41  1941.0     shag rugs
# 2  Living Characters       3061.0           Oct-74  1974.0  rubber ducks
# 3  Living Characters       2961.0           Mar-63  1963.0        storms
# 4  Living Characters       2258.0           Nov-50  1950.0  rubber ducks
#
#    Killability    Weaknesses
# 0            3     apple pie
# 1            3  giant robots
# 2            7     tv static
# 3           10  giant robots
# 4            2       Walmart

# %% [markdown]
# ### The General wants us to assume that all the heros in this new table without entries are deceased and good aligned. Let's update the table with our new data

# %%
outer_merge['ALIVE'] = outer_merge['ALIVE'].fillna('Deceased Charcters')
outer_merge['ALIGN'] = outer_merge['ALIGN'].fillna('Good Characters')
outer_merge.head()
# Out:
#    page_id                                 name  \
# 0   1678.0            Spider-Man (Peter Parker)
# 1   7139.0      Captain America (Steven Rogers)
# 2  64786.0  Wolverine (James \"Logan\" Howlett)
# 3   1868.0    Iron Man (Anthony \"Tony\" Stark)
# 4   2460.0                  Thor (Thor Odinson)
#
#                                    urlslug                ID  \
# 0              \/Spider-Man_(Peter_Parker)   Secret Identity
# 1        \/Captain_America_(Steven_Rogers)   Public Identity
# 2  \/Wolverine_(James_%22Logan%22_Howlett)   Public Identity
# 3    \/Iron_Man_(Anthony_%22Tony%22_Stark)   Public Identity
# 4                    \/Thor_(Thor_Odinson)  No Dual Identity
#
#                 ALIGN         EYE        HAIR              SEX  GSM  \
# 0     Good Characters  Hazel Eyes  Brown Hair  Male Characters  NaN
# 1     Good Characters   Blue Eyes  White Hair  Male Characters  NaN
# 2  Neutral Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 3     Good Characters   Blue Eyes  Black Hair  Male Characters  NaN
# 4     Good Characters   Blue Eyes  Blond Hair  Male Characters  NaN
#
#                ALIVE  APPEARANCES FIRST APPEARANCE    Year    Affinities  \
# 0  Living Characters       4043.0           Aug-62  1962.0    bubble gum
# 1  Living Characters       3360.0           Mar-41  1941.0     shag rugs
# 2  Living Characters       3061.0           Oct-74  1974.0  rubber ducks
# 3  Living Characters       2961.0           Mar-63  1963.0        storms
# 4  Living Characters       2258.0           Nov-50  1950.0  rubber ducks
#
#    Killability    Weaknesses
# 0            3     apple pie
# 1            3  giant robots
# 2            7     tv static
# 3           10  giant robots
# 4            2       Walmart

# %% [markdown]
# ### The General wants us to update our dates of first appearances so that we can more easily work with the data. Add a new column with the updated datetime field called "Character Created". If the date is blank, use 0 as the value (we will need to filter out these values during our analysis).

# %%
outer_merge['Character Created'] = outer_merge['FIRST APPEARANCE'].fillna(0)

# %% [markdown]
# ### Who was the first superhero to appear in our table?

# %%
# The Human Torch was the first to appear
pd.pivot_table(outer_merge, values=['name'], index=['Year','Character Created'], aggfunc=sum)
# Out:
#                                                                        name
# Year   Character Created
# 1939.0 Dec-39             Pete Johnson (Earth-616)Drayson (Earth-616)Jos...
#        Oct-39             Human Torch (Android) (Earth-616)Thomas Hallow...
# 1940.0 Apr-40             Richard Jones (Phantom Reporter) (Earth-616)Ea...
#        Aug-40             Makkari (Earth-616)Azura (Earth-616)Kro (Earth...
#        Dec-40             Jeffrey Mace (Earth-616)Mary Morgan (Earth-616...
#        Feb-40             Electro (Robot) (Earth-616)Philo Zogolowski (E...
#        Jan-40             Betty Dean (Earth-616)Jack Castle (Earth-616)J...
#        Jul-40             Gor (Earth-616)Chadak (Earth-616)Hook (Earth-6...
#        Jun-40             Carl Burgess (Earth-616)Varen David (Earth-616...
#        Mar-40             Dynamic Man (Earth-616)Flexo (Earth-616)Dakor ...
#        May-40             Donovan Gorman (Earth-616)Jerry Alton (Earth-6...
#        Nov-40             Aarkus (Earth-616)Enoch Mason (Earth-616)Betty...
#        Oct-40             Folma (Earth-616)Grey Gidden (Earth-616)Stephe...
#        Sep-40             Thomas Raymond (Earth-616)Adolf Hitler (Earth-...
# 1941.0 Apr-41             Elizabeth Barstow (Earth-616)Elton Morrow (Ear...
#        Aug-41             Johann Shmidt (Earth-616)Robert Frank (Earth-6...
#        Dec-41             Witness (WWII) (Earth-616)Eric Hertz (Earth-61...
#        Feb-41             Pindar (Earth-616)Gos Carlton (Earth-616)Karl ...
#        Jan-41             Doctor Lorrof (Earth-616)Professor Donaire (Ea...
#        Jul-41                C.J. Miller (Earth-616)Prince Itor (Earth-616)
#        Jun-41             Henry Tinkelbaum (Earth-616)Geoffrey Vandergil...
#        Mar-41             Captain America (Steven Rogers)James Buchanan ...
#        May-41             Butterfly (Vitrioli) (Earth-616)Craig Talbot (...
#        Nov-41             Dan Kane (Earth-616)Pat Murphy (Earth-616)Admi...
#        Oct-41             Kevin Marlow (Earth-616)Florence von Ward (Ear...
#        Sep-41             Winston Churchill (Earth-616)Larry Scott (Eart...
# 1942.0 Apr-42             Roddy Colt (Earth-616)Napoleon Sickles (Earth-...
#        Aug-42             Carl Burgos (Earth-616)Martin Goodman (Earth-6...
#        Dec-42             Doug Johnson (Earth-616)Marla Drake (Earth-616...
#        Feb-42             James Jankovicz (Earth-616)Wump Jump (Earth-61...
# ...                                                                     ...
# 2011.0 Apr-11             Aaron MacKenzie (Earth-616)Katherine Glover (E...
#        Aug-11             Leah (Earth-616)Donna Kiel (Earth-616)Adam (Ea...
#        Dec-11             Kubark (Earth-616)Ava Ayala (Earth-616)Dagan S...
#        Feb-11             Scorn (Symbiote) (Earth-616)Winsor (Earth-616)...
#        Jan-11             Max Modell (Earth-616)Sajani Jaffrey (Earth-61...
#        Jul-11             Lord Deathstrike (Earth-616)Harper Simmons (Ea...
#        Jun-11             En Sabah Nur (Evan Sabahnur) (Earth-616)Ikol (...
#        Mar-11             George Tarleton (M.O.D.O.K. Superior) (Earth-6...
#        May-11             Andrew Forson (Earth-616)Annie (LMD) (Earth-61...
#        Nov-11             Nighteyes (Earth-616)Quickshot (Earth-616)Visi...
#        Oct-11             Rachel Cole (Earth-616)Oscar Clemons (Earth-61...
#        Sep-11             Broo (Earth-616)Kirsten McDuffie (Earth-616)Ka...
# 2012.0 Apr-12             Parvez (Earth-616)Weapon III (Earth-616)Firebr...
#        Aug-12             Onome (Earth-616)Leonid Novokov (Earth-616)Ixc...
#        Dec-12             Darla Deering (Earth-616)Jia Jing (Earth-616)T...
#        Feb-12             Thori (Earth-616)Allison Kemp (Earth-616)Death...
#        Jan-12             Nicholas Fury, Jr. (Earth-616)Phillip Coulson ...
#        Jul-12             Omega Black (Earth-616)Omega Red (Omega Clan) ...
#        Jun-12             Kashmir Vennema (Earth-616)Dennis Wells (Earth...
#        Mar-12             Mar\u00eda Aracely Penalba (Earth-616)Shingen ...
#        May-12             Smithy (Earth-616)Harvester (Assassin) (Earth-...
#        Nov-12             Gabriel Shepherd (Earth-616)Ben Goldendawn (Ea...
#        Oct-12             Lucky (Earth-616)Katherine Kiernan (Earth-616)...
#        Sep-12             Helen Cobb (Earth-616)Zoe Walsh (Earth-616)Rem...
# 2013.0 Apr-13             Fabio Medina (Earth-616)Eva Alexander (Earth-6...
#        Feb-13             Benjamin Deeds (Earth-616)Isabel Kane (Earth-6...
#        Jan-13             Eva Bell (Earth-616)Christopher Muse (Earth-61...
#        Jun-13             Miss Coriander (Earth-616)Ikari (Earth-616)Val...
#        Mar-13             Nightmask (Earth-616)Randall Jessup (Earth-616...
#        May-13             Kevin Connor (Earth-616)Anna Maria Marconi (Ea...
#
# [832 rows x 1 columns]

# %% [markdown]
# ### Who was the lastest superhero to appear in our table?

# %%
# Miss Coriander was the last superhero to appear in the table.

pd.pivot_table(outer_merge, values=['name'], index=['Year','Character Created'], aggfunc=sum).sort(ascending=False)
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: FutureWarning: sort(....) is deprecated, use sort_index(.....)
#   app.launch_new_instance()
#                                                                        name
# Year   Character Created
# 2013.0 May-13             Kevin Connor (Earth-616)Anna Maria Marconi (Ea...
#        Mar-13             Nightmask (Earth-616)Randall Jessup (Earth-616...
#        Jun-13             Miss Coriander (Earth-616)Ikari (Earth-616)Val...
#        Jan-13             Eva Bell (Earth-616)Christopher Muse (Earth-61...
#        Feb-13             Benjamin Deeds (Earth-616)Isabel Kane (Earth-6...
#        Apr-13             Fabio Medina (Earth-616)Eva Alexander (Earth-6...
# 2012.0 Sep-12             Helen Cobb (Earth-616)Zoe Walsh (Earth-616)Rem...
#        Oct-12             Lucky (Earth-616)Katherine Kiernan (Earth-616)...
#        Nov-12             Gabriel Shepherd (Earth-616)Ben Goldendawn (Ea...
#        May-12             Smithy (Earth-616)Harvester (Assassin) (Earth-...
#        Mar-12             Mar\u00eda Aracely Penalba (Earth-616)Shingen ...
#        Jun-12             Kashmir Vennema (Earth-616)Dennis Wells (Earth...
#        Jul-12             Omega Black (Earth-616)Omega Red (Omega Clan) ...
#        Jan-12             Nicholas Fury, Jr. (Earth-616)Phillip Coulson ...
#        Feb-12             Thori (Earth-616)Allison Kemp (Earth-616)Death...
#        Dec-12             Darla Deering (Earth-616)Jia Jing (Earth-616)T...
#        Aug-12             Onome (Earth-616)Leonid Novokov (Earth-616)Ixc...
#        Apr-12             Parvez (Earth-616)Weapon III (Earth-616)Firebr...
# 2011.0 Sep-11             Broo (Earth-616)Kirsten McDuffie (Earth-616)Ka...
#        Oct-11             Rachel Cole (Earth-616)Oscar Clemons (Earth-61...
#        Nov-11             Nighteyes (Earth-616)Quickshot (Earth-616)Visi...
#        May-11             Andrew Forson (Earth-616)Annie (LMD) (Earth-61...
#        Mar-11             George Tarleton (M.O.D.O.K. Superior) (Earth-6...
#        Jun-11             En Sabah Nur (Evan Sabahnur) (Earth-616)Ikol (...
#        Jul-11             Lord Deathstrike (Earth-616)Harper Simmons (Ea...
#        Jan-11             Max Modell (Earth-616)Sajani Jaffrey (Earth-61...
#        Feb-11             Scorn (Symbiote) (Earth-616)Winsor (Earth-616)...
#        Dec-11             Kubark (Earth-616)Ava Ayala (Earth-616)Dagan S...
#        Aug-11             Leah (Earth-616)Donna Kiel (Earth-616)Adam (Ea...
#        Apr-11             Aaron MacKenzie (Earth-616)Katherine Glover (E...
# ...                                                                     ...
# 1942.0 Feb-42             James Jankovicz (Earth-616)Wump Jump (Earth-61...
#        Dec-42             Doug Johnson (Earth-616)Marla Drake (Earth-616...
#        Aug-42             Carl Burgos (Earth-616)Martin Goodman (Earth-6...
#        Apr-42             Roddy Colt (Earth-616)Napoleon Sickles (Earth-...
# 1941.0 Sep-41             Winston Churchill (Earth-616)Larry Scott (Eart...
#        Oct-41             Kevin Marlow (Earth-616)Florence von Ward (Ear...
#        Nov-41             Dan Kane (Earth-616)Pat Murphy (Earth-616)Admi...
#        May-41             Butterfly (Vitrioli) (Earth-616)Craig Talbot (...
#        Mar-41             Captain America (Steven Rogers)James Buchanan ...
#        Jun-41             Henry Tinkelbaum (Earth-616)Geoffrey Vandergil...
#        Jul-41                C.J. Miller (Earth-616)Prince Itor (Earth-616)
#        Jan-41             Doctor Lorrof (Earth-616)Professor Donaire (Ea...
#        Feb-41             Pindar (Earth-616)Gos Carlton (Earth-616)Karl ...
#        Dec-41             Witness (WWII) (Earth-616)Eric Hertz (Earth-61...
#        Aug-41             Johann Shmidt (Earth-616)Robert Frank (Earth-6...
#        Apr-41             Elizabeth Barstow (Earth-616)Elton Morrow (Ear...
# 1940.0 Sep-40             Thomas Raymond (Earth-616)Adolf Hitler (Earth-...
#        Oct-40             Folma (Earth-616)Grey Gidden (Earth-616)Stephe...
#        Nov-40             Aarkus (Earth-616)Enoch Mason (Earth-616)Betty...
#        May-40             Donovan Gorman (Earth-616)Jerry Alton (Earth-6...
#        Mar-40             Dynamic Man (Earth-616)Flexo (Earth-616)Dakor ...
#        Jun-40             Carl Burgess (Earth-616)Varen David (Earth-616...
#        Jul-40             Gor (Earth-616)Chadak (Earth-616)Hook (Earth-6...
#        Jan-40             Betty Dean (Earth-616)Jack Castle (Earth-616)J...
#        Feb-40             Electro (Robot) (Earth-616)Philo Zogolowski (E...
#        Dec-40             Jeffrey Mace (Earth-616)Mary Morgan (Earth-616...
#        Aug-40             Makkari (Earth-616)Azura (Earth-616)Kro (Earth...
#        Apr-40             Richard Jones (Phantom Reporter) (Earth-616)Ea...
# 1939.0 Oct-39             Human Torch (Android) (Earth-616)Thomas Hallow...
#        Dec-39             Pete Johnson (Earth-616)Drayson (Earth-616)Jos...
#
# [832 rows x 1 columns]

# %% [markdown]
# ### What was the date difference between their appearances?

# %%
# 99 years and 8 months

2013 - 1913
# Out:
# 100
